# %%
import pandas as pd
import requests

# %%
df = pd.read_excel("data/original/original_data.xlsb", engine="pyxlsb", sheet_name=1, usecols=['Адреса', 'Номер АЗС', 'Область'])
df.head()
# Out:
#                                               Адреса Номер АЗС  \
# 0                  м. Київ, просп. Леся Курбаса, 2 Ж    АЗС-47
# 1             м. Київ, вул. Новокостянтинівська, 4 Ж    АЗС-62
# 2                     м. Стрий, вул. Болехівська, 49    АЗС-23
# 3  Надвірнянський р-н, м. Надвірна, вул. Вокзальн...    АЗС-21
# 4            м. Київ, просп. Академіка Палладіна, 33    АЗС-63
#
#             Область
# 0           м. Київ
# 1           м. Київ
# 2             Львів
# 3  Івано-Франківськ
# 4           м. Київ

# %%
def get_lat_lon(address):
    api_key = 'zvh0VVrQoh5levSf5e1dBBQN5QqPUvPzy-xyCrVx_Qg'
    if 'Саймона Літмана' in address:
        address = 'м. Одеса, вул. Пестеля, 2 А'
    if 'Фастівський р-н, тг Боярська' in address:
        lat = 50.358519581545416
        lon = 30.343913785599327
        return lat, lon
    if 'Одеський р-н, с/р Нерубайська, автодорога  Київ-Одеса 454км, будинок 1' in address:
        address = 'Одеський р-н, Нерубайське, автодорога  Київ-Одеса 454км, будинок 1'
    if address == 'Дніпропетровська обл.,  сщ/рада  Слобожанська,  комплекс будівель та споруд':
        lat = 48.548346
        lon = 35.073624
        return lat, lon
    if 'Рівненський р-н, с/рада Шпанівська, комплекс будівель та споруд №1' in address:
        lat = 50.645199
        lon = 26.200689
        return lat, lon
    if 'Житомирський р-н, с/р Левківська, автодорога Київ-Чоп (на Будапешт через Львів, Мукачеве, Ужгород), 127км+198м' in address:
        lat = 50.286393
        lon = 28.826337
        return lat, lon
    if 'с/р Новоолександрівська, автодорога Бориспіль-Дніпропетровськ-Запоріжжя, 417км+680м' in address:
        lat = 48.360481
        lon = 35.027386
        return lat, lon
    if 'Бориспільський р-н, с/р Іванківська, автодорога Київ-Харків-Довжанський, 45км+20м' in address:
        lat = 50.319615
        lon = 31.033856
        return lat, lon
    if 'Уманський р-н, с/р Фурманська, автодорога Київ-Одеса, 226км+700м' in address:
        lat = 48.566059
        lon = 30.230684
        return lat, lon
    if 'Фастівський р-н, с/р Гатненська, автодорога Київ-Одеса, 15км+450м' in address:
        lat = 50.344203
        lon = 30.41814
        return lat, lon
    if 'Фастівський р-н, селище Чабани, Одеське шосе, 12' in address:
        lat = 50.354504
        lon = 30.435674
        return lat, lon
    if "м. Підгородне, автодорога Знам'янка-Луганськ-Ізварине, 227км+580м" in address:
        lat = 48.581909
        lon = 35.129894
        return lat, lon
    if "Уманський р-н, с/р Ладижинська, автодорога Київ-Одеса 226км+310м (ліворуч)" in address:
        lat = 48.567394
        lon = 30.232208
        return lat, lon
    if "Одеський р-н, с/р Нерубайська, автодорога  Київ-Одеса 454км, будинок 2" in address:
        lat = 46.574039
        lon = 30.573563
        return lat, lon
    if "с/р Новоолександрівська, автодорога Бориспіль-Дніпропетровськ-Запоріжжя, 417км+540м" in address:
        lat = 48.360587
        lon = 35.02671
        return lat, lon
    url = f"https://geocode.search.hereapi.com/v1/geocode?q={address}&apiKey={api_key}"
    response = requests.get(url)
    print(f"HTTP Status Code: {response.status_code}")
    
    if response.status_code == 200:
        data = response.json()
        if data['items']:
            lat = data['items'][0]['position']['lat']
            lon = data['items'][0]['position']['lng']
            return lat, lon
        else:
            print("No results found for the given address.")
            return None, None
    else:
        print(f"Request failed with status: {response.status_code}")
        return None, None

# %%
df.rename(columns={
    'Адреса': 'Address',
    'Номер АЗС': 'Number',
    'Область': 'Region'
}, inplace=True)
df = df[:57]
df
# Out:
#                                               Address  Number  \
# 0                   м. Київ, просп. Леся Курбаса, 2 Ж  АЗС-47
# 1              м. Київ, вул. Новокостянтинівська, 4 Ж  АЗС-62
# 2                      м. Стрий, вул. Болехівська, 49  АЗС-23
# 3   Надвірнянський р-н, м. Надвірна, вул. Вокзальн...  АЗС-21
# 4             м. Київ, просп. Академіка Палладіна, 33  АЗС-63
# 5   с/р Новоолександрівська, вздовж АД М-04 Знам'я...  АЗС-39
# 6            м. Івано-Франківськ, вул. Хриплинська, 9  АЗС-01
# 7   Бучанський р-н, с. Калинівка, вул. Київська 50/52  АЗС-07
# 8              м. Київ, просп. Володимира Івасюка, 1а  АЗС-36
# 9   Бориспільський р-н, с. Щасливе, Харківське шос...  АЗС-53
# 10                     м. Київ, просп. Шухевича Р., 5  АЗС-30
# 11                  м. Київ, просп. Броварський, 20 З  АЗС-29
# 12        м. Харків, вул. Гвардійців-Широнінців, 83 А  АЗС-35
# 13                  м. Київ, вул. Семена Скляренка, 4  АЗС-61
# 14             м. Чернівці, вул. Галицький шлях, 46 М  АЗС-42
# 15  с/р Новоолександрівська, автодорога Бориспіль-...  АЗС-20
# 16  Одеський р-н, с/р Нерубайська, автодорога  Киї...  АЗС-22
# 17  Уманський р-н, с/р Ладижинська, автодорога Киї...  АЗС-44
# 18  Фастівський р-н, с/р Гатненська, автодорога Ки...  АЗС-45
# 19  м. Підгородне, автодорога Знам'янка-Луганськ-І...  АЗС-35
# 20   Фастівський р-н, селище Чабани, Одеське шосе, 12  АЗС-44
# 21  Ужгородський р-н, с. Соломоново, автодорога Ки...  АЗС-29
# 22  Харківська обл., Харківський р-н, селище Пісоч...  АЗС-33
# 23    Львівський р-н, с. Гамаліївка, вул. Київська, 2  АЗС-30
# 24                     м. Сарни, вул. Варшавська, 4 Б  АЗС-25
# 25   Харківський р-н, с. Мала Рогань, вул. Шосейна, 2  АЗС-34
# 26  Уманський р-н, с/р Фурманська, автодорога Київ...  АЗС-46
# 14       Чернівецька  48.31605  25.911680
# 15   Дніпропетровськ       NaN        NaN
# 16             Одеса       NaN        NaN
# 17           Черкаси       NaN        NaN
# 18              Київ       NaN        NaN
# 19   Дніпропетровськ       NaN        NaN
# 20              Київ       NaN        NaN
# 21        Закарпаття  48.43470  22.165290
# 22            Харків  49.95605  36.110870
# 23             Львів  48.88627  36.299220
# 24             Рівне  51.31633  26.619650
# 25            Харків  49.81882  36.037950
# 26           Черкаси       NaN        NaN
# 27             Львів  49.17718  23.770170
# 28             Львів  50.06559  25.163560
# 29        Кіровоград  48.66523  33.082070
# 30              Київ       NaN        NaN
# 31             Львів  49.78270  23.639380
# 32             Рівне  50.67244  26.271480
# 33  Івано-Франківськ  48.94194  24.739010
# 34             Львів  49.75055  24.015610
# 35             Львів  49.76575  24.012930
# 36           Полтава  50.22116  32.517180
# 37   Дніпропетровськ       NaN        NaN
# 38  Івано-Франківськ  48.95336  24.701950
# 39           Житомир       NaN        NaN
# 40             Рівне  50.60912  26.377980
# 41             Рівне       NaN        NaN
# 42   Дніпропетровськ       NaN        NaN
# 43              Київ  50.41829  29.839050
# 44             Одеса  46.53692  30.653600
# 45  Івано-Франківськ  49.03347  24.429620
# 46              Київ  50.65631  29.895120
# 47             Львів  49.96054  23.146100
# 48           м. Київ  50.41115  30.569740
# 49  Івано-Франківськ  48.53851  25.005750
# 50              Київ  50.35852  30.343914
# 51           м. Київ  50.53378  30.608210
# 52   Дніпропетровськ  48.41123  35.038680
# 53             Одеса  46.47933  30.690400
# 54              Київ  50.34903  30.955350
# 55             Львів  49.83580  24.071400
# 56            Волинь  50.86320  24.163080

# %%
latitude = []
longitude = []
for i in df['Address']:
    response = get_lat_lon(i)
    latitude.append(response[0])
    longitude.append(response[1])
# Out:
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200
# HTTP Status Code: 200

# %%
df['Latitude'] = latitude
df['Longitude'] = longitude

# %%
df
# Out:
#                                               Address  Number  \
# 0                   м. Київ, просп. Леся Курбаса, 2 Ж  АЗС-47
# 1              м. Київ, вул. Новокостянтинівська, 4 Ж  АЗС-62
# 2                      м. Стрий, вул. Болехівська, 49  АЗС-23
# 3   Надвірнянський р-н, м. Надвірна, вул. Вокзальн...  АЗС-21
# 4             м. Київ, просп. Академіка Палладіна, 33  АЗС-63
# 5   с/р Новоолександрівська, вздовж АД М-04 Знам'я...  АЗС-39
# 6            м. Івано-Франківськ, вул. Хриплинська, 9  АЗС-01
# 7   Бучанський р-н, с. Калинівка, вул. Київська 50/52  АЗС-07
# 8              м. Київ, просп. Володимира Івасюка, 1а  АЗС-36
# 9   Бориспільський р-н, с. Щасливе, Харківське шос...  АЗС-53
# 10                     м. Київ, просп. Шухевича Р., 5  АЗС-30
# 11                  м. Київ, просп. Броварський, 20 З  АЗС-29
# 50  Фастівський р-н, тг Боярська, автодорога Київс...  АЗС-78
# 51                    м. Київ, вул. Милославська, 2 А  АЗС-28
# 52         м.Дніпро, Соборний р-н, вул.Космічна, 32 Б  АЗС-55
# 53                м. Одеса, вул. Саймона Літмана, 2 А  АЗС-45
# 54  Бориспільський р-н, с/р Іванківська, автодорог...  АЗС-33
# 55                    м.Львів, вул.Личаківська, 152-Б  АЗС-99
# 56  Володимирський р-н, м. Устилуг, вул. Володимир...  АЗС-53
#
#               Region   Latitude  Longitude
# 0            м. Київ  50.431040  30.390370
# 1            м. Київ  50.482070  30.487250
# 2              Львів  49.247780  23.856100
# 3   Івано-Франківськ  48.623070  24.583510
# 4            м. Київ  50.467540  30.356800
# 5    Дніпропетровськ  48.563550  39.197000
# 6   Івано-Франківськ  48.914760  24.729130
# 7               Київ  50.419410  29.842060
# 8            м. Київ  50.498570  30.582300
# 9               Київ  50.315630  31.044870
# 10           м. Київ  50.494700  30.579210
# 11           м. Київ  50.471380  30.670620
# 12            Харків  50.027880  36.352960
# 13           м. Київ  50.491690  30.470310
# 14       Чернівецька  48.316050  25.911680
# 15   Дніпропетровськ  48.360587  35.026710
# 16             Одеса  46.574039  30.573563
# 17           Черкаси  48.567394  30.232208
# 18              Київ  50.344203  30.418140
# 19   Дніпропетровськ  48.581909  35.129894
# 20              Київ  50.354504  30.435674
# 21        Закарпаття  48.434700  22.165290
# 22            Харків  49.956050  36.110870
# 23             Львів  48.886270  36.299220
# 24             Рівне  51.316330  26.619650
# 25            Харків  49.818820  36.037950
# 26           Черкаси  48.566059  30.230684
# 27             Львів  49.177180  23.770170
# 28             Львів  50.065590  25.163560
# 29        Кіровоград  48.665230  33.082070
# 30              Київ  50.319615  31.033856
# 31             Львів  49.782700  23.639380
# 32             Рівне  50.672440  26.271480
# 33  Івано-Франківськ  48.941940  24.739010
# 34             Львів  49.750550  24.015610
# 35             Львів  49.765750  24.012930
# 36           Полтава  50.221160  32.517180
# 37   Дніпропетровськ  48.360481  35.027386
# 38  Івано-Франківськ  48.953360  24.701950
# 39           Житомир  50.286393  28.826337
# 40             Рівне  50.609120  26.377980
# 41             Рівне  50.645199  26.200689
# 42   Дніпропетровськ  48.548346  35.073624
# 43              Київ  50.418290  29.839050
# 44             Одеса  46.536920  30.653600
# 45  Івано-Франківськ  49.033470  24.429620
# 46              Київ  50.656310  29.895120
# 47             Львів  49.960540  23.146100
# 48           м. Київ  50.411150  30.569740
# 49  Івано-Франківськ  48.538510  25.005750
# 50              Київ  50.358520  30.343914
# 51           м. Київ  50.533780  30.608210
# 52   Дніпропетровськ  48.411230  35.038680
# 53             Одеса  46.479330  30.690400
# 54              Київ  50.349030  30.955350
# 55             Львів  49.835800  24.071400
# 56            Волинь  50.863200  24.163080

# %%
df.to_csv('data/locations.csv')
